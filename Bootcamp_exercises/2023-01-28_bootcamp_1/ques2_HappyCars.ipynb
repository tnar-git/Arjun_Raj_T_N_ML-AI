# %%
import pandas as pd

# %%
csv_file='HappyCars.csv'

df=pd.read_csv(csv_file)
df
# Out:
#       CustomerID  FirstName MiddleName  LastName            BirthDate  \
# 0          11004  Elizabeth        NaN   Johnson  1968-08-08 00:00:00
# 1          11006      Janet          G   Alvarez  1965-12-06 00:00:00
# 2          11007      Marco        NaN     Mehta  1964-05-09 00:00:00
# 3          11008        Rob        NaN   Verhoff  1964-07-07 00:00:00
# 4          11009    Shannon          C   Carlson  1964-04-01 00:00:00
# ...          ...        ...        ...       ...                  ...
# 9995       29459      Marco          L  Malhotra  1977-05-04 00:00:00
# 9996       29460     Andres          E   Chander  1977-03-15 00:00:00
# 9997       29470     Nathan        NaN   Roberts  1960-08-25 00:00:00
# 9998       29472      Lacey          M    Sharma  1960-03-14 00:00:00
# 9999       29474      Jaime          B      Raje  1959-10-04 00:00:00
#
#      MaritalStatus  YearlyIncome Gender  TotalChildren  NumberChildrenAtHome  \
# 0                S  75001-100000      F            5.0                     5
# 1                S   50001-75000      F            0.0                     0
# 2                M   50001-75000      M            3.0                     3
# 3                S   50001-75000      F            4.0                     4
# 4                S   50001-75000      M            0.0                     0
# ...            ...           ...    ...            ...                   ...
# 9995             S       0-25000      M            0.0                     0
# 9996             M       0-25000      M            0.0                     0
# 9997             S       0-25000      M            1.0                     1
# 9998             M       0-25000      F            1.0                     1
# 9999             M       0-25000      M            2.0                     0
#
#             Education    Occupation  HomeOwner CommuteDistance  \
# 0          Bachelors   Professional       True       1-2 Miles
# 1          Bachelors   Professional       True      5-10 Miles
# 2          Bachelors   Professional       True       0-1 Miles
# 3          Bachelors   Professional       True       10+ Miles
# 4          Bachelors   Professional      False      5-10 Miles
# ...               ...           ...        ...             ...
# 9995      High School        Manual      False       2-5 Miles
# 9996      High School        Manual      False       0-1 Miles
# 9997      High School        Manual      False       1-2 Miles
# 9998      High School        Manual      False       1-2 Miles
# 9999  Partial College        Manual      False       0-1 Miles
#
#       NumberOfPurchases  ProfitGenerated
# 0                     5       10351.6657
# 1                     1       25636.9867
# 2                     2        9221.5725
# 3                     3       16556.0652
# 4                     1       27955.7062
# ...                 ...              ...
# 9995                  1        3260.0490
# 9996                  2        1966.8401
# 9997                  1        1934.2584
# 9998                  1        1154.3211
# 9999                  1        1601.0582
#
# [10000 rows x 16 columns]

# %%
### Q.What are the column names of the DataFrame?
# print(df.columns)
for col in df.columns:
    print(col)
# Out:
# CustomerID
# FirstName
# MiddleName
# LastName
# BirthDate
# MaritalStatus
# YearlyIncome
# Gender
# TotalChildren
# NumberChildrenAtHome
# Education
# Occupation
# HomeOwner
# CommuteDistance
# NumberOfPurchases
# ProfitGenerated

# %%
### 3 What are the data types of the columns?
df.dtypes
# df.info()
# for col in df.columns:
#     print(col.dtype)
# Out:
# CustomerID                int64
# FirstName                object
# MiddleName               object
# LastName                 object
# BirthDate                object
# MaritalStatus            object
# YearlyIncome             object
# Gender                   object
# TotalChildren           float64
# NumberChildrenAtHome      int64
# Education                object
# Occupation               object
# HomeOwner                  bool
# CommuteDistance          object
# NumberOfPurchases         int64
# ProfitGenerated         float64
# dtype: object

# %%
### 4. How many non-missing values are in each column?


print(df.count(axis=0))

## using for loop
# for col in df.columns:
#     b=df[col].dropna()
#     print(col,' ',len(b))
# Out:
# CustomerID              10000
# FirstName               10000
# MiddleName               5730
# LastName                10000
# BirthDate               10000
# MaritalStatus           10000
# YearlyIncome            10000
# Gender                  10000
# TotalChildren            9992
# NumberChildrenAtHome    10000
# Education               10000
# Occupation              10000
# HomeOwner               10000
# CommuteDistance         10000
# NumberOfPurchases       10000
# ProfitGenerated         10000
# dtype: int64

# %%
### 5. What is the average, minimum, and maximum value of each numeric column?

### without for loop
print('mean of each column :-')
print(df.mean(axis=0,numeric_only=True))
print('max of each column :-')
print(df.max(axis=0,numeric_only=True))
print('min of each column :-')
print(df.min(axis=0,numeric_only=True))
# type(df.min(axis=0,numeric_only=True))
# df.max()
# df.mean()
### using for loop
# for col in df.columns:
#     try :
#         if df[col].dtype== 'bool':
#             break
#         print('mean of ',col,' is ',df[col].mean())
#         print('maximum of ',col,' is ',df[col].max())
#         print('minimum of ',col,' is ',df[col].min())
# #         print('mean of ',col,' is ',df[col].mean())
#     except:
#         pass
# Out:
# mean of each column :-
# CustomerID              20325.469300
# TotalChildren               2.071958
# NumberChildrenAtHome        1.081300
# HomeOwner                   0.646400
# NumberOfPurchases           2.251300
# ProfitGenerated         12510.868637
# dtype: float64
# max of each column :-
# CustomerID                   29474
# TotalChildren                  5.0
# NumberChildrenAtHome             6
# HomeOwner                     True
# NumberOfPurchases                7
# ProfitGenerated         61196.7654
# dtype: object
# min of each column :-
# CustomerID                 11004
# TotalChildren                0.0
# NumberChildrenAtHome           0
# HomeOwner                  False
# NumberOfPurchases              1
# ProfitGenerated         796.1449
# dtype: object

# %%
### 6. What is the unique value count for each categorical column?

    
### without using for loop
print(df.nunique(axis=0))

### using for loop
# for col in df.columns:
#     b=df[col].drop_duplicates()
#     print(col,' ',len(b))
# Out:
# CustomerID              10000
# FirstName                 628
# MiddleName                 37
# LastName                  317
# BirthDate                6105
# MaritalStatus               2
# YearlyIncome                5
# Gender                      2
# TotalChildren               6
# NumberChildrenAtHome        7
# Education                   5
# Occupation                  5
# HomeOwner                   2
# CommuteDistance             5
# NumberOfPurchases           7
# ProfitGenerated          9999
# dtype: int64

# %%
### 7. How many missing values are in each column?
for col in df.columns:
    b=df[col].dropna()
    print(col,' ',len(df[col])-len(b))
# Out:
# CustomerID   0
# FirstName   0
# MiddleName   4270
# LastName   0
# BirthDate   0
# MaritalStatus   0
# YearlyIncome   0
# Gender   0
# TotalChildren   8
# NumberChildrenAtHome   0
# Education   0
# Occupation   0
# HomeOwner   0
# CommuteDistance   0
# NumberOfPurchases   0
# ProfitGenerated   0

# %%
### 8. What is the most common value in each categorical column?


print('most common values in the respective columns are :-')

### remove columns that have all entries unique

mode_df=df.mode(axis=0)
for col in mode_df.columns:
    if len(mode_df[col].dropna())==len(df[col]):
        mode_df.drop(columns=col,inplace=True)
new_mode_df=mode_df.mode(axis=0)



### nuanced way for when there multiple modes
if not new_mode_df.shape[0]==1:
    for col in new_mode_df.columns:
        modes_in_col_series=new_mode_df[col].dropna()
        modes_list=[mode for mode in modes_in_col_series]

        if len(modes_list) >1:
            print('most common values in ' ,col, ' are ',end='')
            for i in range(len(modes_list)-1):
                print(modes_list[i],', '  )
            print(modes_list[len(modes_list)-1], end='\n')
        else:
            print('most common value in ' ,col, ' is ',end='')
            print(modes_list[0],end='\n')
else:
    
    ### easy way
    print(new_mode_df.iloc[0,:])
# Out:
# most common values in the respective columns are :-
# most common value in  FirstName  is Devin
# most common value in  MiddleName  is A
# most common value in  LastName  is Diaz
# most common values in  BirthDate  are 1964-07-14 00:00:00 ,
# 1965-08-27 00:00:00
# most common value in  MaritalStatus  is M
# most common value in  YearlyIncome  is 50001-75000
# most common value in  Gender  is M
# most common value in  TotalChildren  is 0.0
# most common value in  NumberChildrenAtHome  is 0.0
# most common value in  Education  is Partial College
# most common value in  Occupation  is Professional
# most common value in  HomeOwner  is True
# most common value in  CommuteDistance  is 0-1 Miles
# most common value in  NumberOfPurchases  is 2.0
# most common value in  ProfitGenerated  is 7224.594

# %%
#### 9. What is the correlation coefficient between each pair of numeric columns?
df.corr()
# Out:
#                       CustomerID  TotalChildren  NumberChildrenAtHome  \
# CustomerID              1.000000      -0.002717             -0.033829
# TotalChildren          -0.002717       1.000000              0.584350
# NumberChildrenAtHome   -0.033829       0.584350              1.000000
# HomeOwner              -0.102481       0.215814              0.181964
# NumberOfPurchases      -0.023607       0.267432              0.393011
# ProfitGenerated        -0.061831      -0.147321              0.007766
#
#                       HomeOwner  NumberOfPurchases  ProfitGenerated
# CustomerID            -0.102481          -0.023607        -0.061831
# TotalChildren          0.215814           0.267432        -0.147321
# NumberChildrenAtHome   0.181964           0.393011         0.007766
# HomeOwner              1.000000           0.080592         0.171841
# NumberOfPurchases      0.080592           1.000000         0.399030
# ProfitGenerated        0.171841           0.399030         1.000000

# %%
### 10. How is the distribution of each numeric column?
df.hist() 
# for col in df.columns:
#     print(df.dropna()[col].info())
# Out:
# array([[<AxesSubplot:title={'center':'CustomerID'}>,
#         <AxesSubplot:title={'center':'TotalChildren'}>],
#        [<AxesSubplot:title={'center':'NumberChildrenAtHome'}>,
#         <AxesSubplot:title={'center':'NumberOfPurchases'}>],
#        [<AxesSubplot:title={'center':'ProfitGenerated'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
### 11. How many observations are in each category of a categorical column?

print(df.count(axis=0))

# print('answer is ', len(df.index))
# Out:
# CustomerID              10000
# FirstName               10000
# MiddleName               5730
# LastName                10000
# BirthDate               10000
# MaritalStatus           10000
# YearlyIncome            10000
# Gender                  10000
# TotalChildren            9992
# NumberChildrenAtHome    10000
# Education               10000
# Occupation              10000
# HomeOwner               10000
# CommuteDistance         10000
# NumberOfPurchases       10000
# ProfitGenerated         10000
# dtype: int64

# %%
### 12. What is the median value of each numeric column?
df.median(numeric_only=True)
# Out:
# CustomerID              20367.0000
# TotalChildren               2.0000
# NumberChildrenAtHome        0.0000
# HomeOwner                   1.0000
# NumberOfPurchases           2.0000
# ProfitGenerated         10622.3929
# dtype: float64

# %%
### 13. What is the range of each numeric column?
import numpy as np
# import 

max_series=df.max(axis=0,numeric_only=True)
# print('min of each column :-')
min_series=df.min(axis=0,numeric_only=True)
range_series=max_series.copy(deep=True)
indices_to_remove=[]
for i in range(len(range_series)):
    if not (type(max_series[i])==np.bool_) and not(type(min_series[i])==np.bool_): 
#         range_series.append((max_series[i]-min_series[i]))
        range_series[i]=(max_series[i]-min_series[i])
    else:
        indices_to_remove.append(i)

range_series.drop(labels=[range_series.index[n] for n in indices_to_remove],inplace=True)

# range_series.drop(labels=indices_to_remove,inplace=True)


print(range_series)
# Out:
# CustomerID                   18470
# TotalChildren                  5.0
# NumberChildrenAtHome             6
# NumberOfPurchases                6
# ProfitGenerated         60400.6205
# dtype: object

# %%
### 14. How many unique values are in each column?

df.nunique(axis=0)
# Out:
# CustomerID              10000
# FirstName                 628
# MiddleName                 37
# LastName                  317
# BirthDate                6105
# MaritalStatus               2
# YearlyIncome                5
# Gender                      2
# TotalChildren               6
# NumberChildrenAtHome        7
# Education                   5
# Occupation                  5
# HomeOwner                   2
# CommuteDistance             5
# NumberOfPurchases           7
# ProfitGenerated          9999
# dtype: int64

# %%
## q.15 find standard deviation
std_series=df.std(axis=0,numeric_only=True)
print(std_series)
# Out:
# CustomerID              5275.706913
# TotalChildren              1.716210
# NumberChildrenAtHome       1.534055
# HomeOwner                  0.478111
# NumberOfPurchases          0.998222
# ProfitGenerated         9010.860651
# dtype: float64

# %%
## q.16 find variance
print(np.square(std_series))
# print(df.var(numeric_only=True))
# Out:
# CustomerID              2.783308e+07
# TotalChildren           2.945377e+00
# NumberChildrenAtHome    2.353326e+00
# HomeOwner               2.285899e-01
# NumberOfPurchases       9.964480e-01
# ProfitGenerated         8.119561e+07
# dtype: float64

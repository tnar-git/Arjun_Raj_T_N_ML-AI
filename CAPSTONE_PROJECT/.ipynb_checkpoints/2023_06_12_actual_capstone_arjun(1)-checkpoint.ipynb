# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

# %%
###
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
my_drive = GoogleDrive(gauth)

### delete gdrive trash files (keras checkpoint files can accumulate in trash) [[2023-06-03]]-0922-27
def clear_gdrive_trash():
    count=0
    # for a_file in my_drive.ListFile({'q': "title contains 'ckpt' and trashed = true"}).GetList():
    for a_file in my_drive.ListFile({'q': "trashed = true"}).GetList():
        count+=1
        # print the name of the file being deleted.
        pass
        # print(a_file['title'])
        print(f'the file {a_file["title"]}, is about to get deleted permanently.')
        # delete the file permanently.
        a_file.Delete()
    print(count)
clear_gdrive_trash()
# Out:
# 0

# %%
### to mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
### to download the dataset from kaggle
# !pip install kaggle
# ! mkdir ~/.kaggle
# ! cp '/content/drive/MyDrive/kaggle.json' ~/.kaggle
# ! chmod 600 ~/.kaggle/kaggle.json
# ! kaggle datasets download shyambhu/hands-and-palm-images-dataset

# ! mkdir /content/drive/MyDrive/ML-AI_capstone_project
# ! mkdir /content/drive/MyDrive/ML-AI_capstone_project/hands_dataset_Afifi/

# ### to copy the downloaded dataset to drive ; so that afterwards the dataset can be copied from drive instead of downloading from kaggle everytime.
# ! cp "/content/hands-and-palm-images-dataset.zip" "/content/drive/MyDrive/ML-AI_capstone_project/hands_dataset_Afifi/"

# %%
! mkdir '/content/drive/MyDrive/ML-AI_capstone_project/models'
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/ML-AI_capstone_project/models’: File exists

# %%
drive_project_folder_path='/content/drive/MyDrive/ML-AI_capstone_project'

# %%
### to copy the dataset zip file from drive to colab filesystem
! cp "/content/drive/MyDrive/ML-AI_capstone_project/hands_dataset_Afifi/hands-and-palm-images-dataset.zip" "/content/hands-and-palm-images-dataset.zip"

# %%
# !unzip hands-and-palm-images-dataset.zip &> /dev/null

# %%
# ! du -sh "/content/hands-and-palm-images-dataset.zip"

# %%
# ! cp -r "/content/Hands" "/content/drive/MyDrive/ML-AI_capstone_project/hands_dataset_Afifi"
# ! cp "/content/HandInfo.csv" "/content/drive/MyDrive/ML-AI_capstone_project/hands_dataset_Afifi"

# %%
### copying directory of images directly from drive is slower that copying the zip file and then unziping [[2023-06-03]]-0924-45

# ! cp -r "/content/drive/MyDrive/ML-AI_capstone_project/hands_dataset_Afifi/Hands" "/content/Hands2"
# ! cp "/content/drive/MyDrive/ML-AI_capstone_project/hands_dataset_Afifi/HandInfo.csv" "/content/HandInfo.csv"

# %%
! pwd
! cd
! pwd
# Out:
# /content
# /content

# %%
import pandas as pd
dataset_dir_path='/content/Hands/Hands'
df=pd.read_csv('HandInfo.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11076 entries, 0 to 11075
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              11076 non-null  int64
#  1   age             11076 non-null  int64
#  2   gender          11076 non-null  object
#  3   skinColor       11076 non-null  object
#  4   accessories     11076 non-null  int64
#  5   nailPolish      11076 non-null  int64
#  6   aspectOfHand    11076 non-null  object
#  7   imageName       11076 non-null  object
#  8   irregularities  11076 non-null  int64
# dtypes: int64(5), object(4)
# memory usage: 778.9+ KB

# %%
df_new=df[(df['aspectOfHand'] == 'palmar right') ]
with open(f'{drive_project_folder_path}/palmar_right_img_filepaths.txt','a+') as f:
    for filename in df_new['imageName']:
        f.write(f'{dataset_dir_path}/{filename}\n')

# %%
# %%bash
# mkdir /content/palmar_right_imgs
# for file in $(cat /content/drive/MyDrive/ML-AI_capstone_project/palmar_right_img_filepaths.txt); do
#  cp "$file" /content/palmar_right_imgs/; done
# Out:
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000085.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000086.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000087.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000088.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000089.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000090.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000113.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000114.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000115.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000116.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000117.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000118.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000140.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000141.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000142.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000143.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000171.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000173.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000174.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000175.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000176.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000177.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000184.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000185.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000186.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000187.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000232.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000233.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000234.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000235.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000243.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000244.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000245.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000246.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000266.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000267.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000268.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000269.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000270.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000271.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000291.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000292.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000293.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000295.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000315.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000316.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000317.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000318.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000319.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000320.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000321.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000385.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000386.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000387.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000388.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000389.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000437.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000438.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000439.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000440.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000441.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000442.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000449.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000450.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000451.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000452.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000454.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000455.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000456.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000457.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000458.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000513.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000514.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000515.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000516.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000517.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000552.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000553.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000554.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000555.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000556.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000565.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000566.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000567.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000568.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000569.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000570.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000611.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000612.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000614.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000615.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000617.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000618.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000624.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000625.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000626.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000627.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000628.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000629.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000630.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000663.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000664.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000665.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000666.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000667.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000668.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000669.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000684.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000685.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000686.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000687.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000688.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000689.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000719.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000720.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000721.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000722.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000723.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000724.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000725.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000726.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000766.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000767.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000768.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000769.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000770.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000771.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000791.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000792.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000793.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000794.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000795.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000830.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000831.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000832.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000833.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000834.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000835.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000836.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000837.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000846.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000847.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000849.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000850.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000851.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000852.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000906.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000907.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000908.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000909.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000910.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000911.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000912.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000920.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000921.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000922.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000923.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000924.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000925.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000926.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000927.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000934.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000935.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000936.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000937.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0000938.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001000.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001001.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001002.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001003.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001004.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001005.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001006.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001007.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001008.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001009.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001018.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001019.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001020.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001021.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001022.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001023.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001024.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001063.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001064.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001065.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001066.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001067.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001068.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001069.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001101.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001102.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001103.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001104.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001105.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001106.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001107.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001108.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001109.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001110.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001149.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001150.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001151.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001152.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001153.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001154.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001176.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001177.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001178.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001179.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001180.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001181.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001216.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001217.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001218.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001219.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001220.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001221.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001222.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001223.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001249.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001250.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001251.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001252.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001253.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001254.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001255.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001256.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001257.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001258.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001259.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001287.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001288.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001289.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001290.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001293.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001294.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001295.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001296.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001317.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001318.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001319.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001320.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001321.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001338.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001339.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001340.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001341.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001342.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001343.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001344.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001357.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001358.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001359.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001360.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001361.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001386.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001387.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001388.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001389.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001390.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001391.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001428.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001429.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001430.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001431.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001432.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001433.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001434.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001504.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001505.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001506.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001507.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001508.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001509.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001510.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001511.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001538.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001539.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001540.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001541.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001542.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001543.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001544.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001545.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001546.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001547.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001579.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001580.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001581.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001582.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001583.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001584.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001585.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001629.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001630.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001631.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001635.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001636.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001637.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001638.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001639.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001640.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001641.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001650.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001651.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001652.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001653.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001654.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001655.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001656.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001657.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001658.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001683.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001684.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001685.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001687.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001688.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001695.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001696.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001697.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001698.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001699.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001725.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001726.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001727.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001728.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001729.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001730.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001731.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001732.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001733.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001765.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001766.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001767.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001768.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001769.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001770.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001771.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001791.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001792.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001793.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001794.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001826.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001827.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001828.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001829.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001830.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001831.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001832.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001863.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001864.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001865.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001866.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001867.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001868.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001869.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001870.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001879.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001880.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001881.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001882.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001883.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001884.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001885.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001886.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001887.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001888.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001889.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001890.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001891.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001892.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001893.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001894.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001895.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001913.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001914.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001915.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001916.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001917.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001924.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001925.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001926.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001927.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001928.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001929.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001930.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001931.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001932.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001967.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001968.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001969.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001970.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001971.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001972.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001981.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001982.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001983.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001984.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001985.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0001986.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002007.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002008.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002009.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002010.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002011.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002012.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002013.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002014.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002050.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002051.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002052.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002053.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002054.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002055.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002056.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002106.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002107.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002108.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002109.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002110.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002111.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002112.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002113.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002145.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002146.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002147.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002148.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002149.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002150.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002151.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002152.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002153.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002154.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002155.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002156.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002157.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002158.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002159.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002160.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002161.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002162.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002163.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002164.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002165.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002166.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002167.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002230.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002231.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002232.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002233.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002234.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002235.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002236.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002237.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002238.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002239.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002240.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002241.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002242.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002243.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002244.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002245.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002246.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002247.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002248.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002249.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002250.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002251.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002252.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002335.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002336.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002337.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002338.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002339.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002340.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002341.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002342.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002343.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002344.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002345.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002346.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002347.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002348.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002349.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002350.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002351.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002352.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002353.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002354.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002355.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002443.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002444.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002445.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002446.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002447.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002448.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002449.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002450.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002548.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002549.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002550.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002551.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002552.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002553.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002554.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002555.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002556.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002557.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002558.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002559.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002560.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002561.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002562.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002563.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002564.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002565.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002566.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002567.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002568.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002569.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002570.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002571.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002572.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002573.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002574.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002645.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002646.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002647.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002648.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002649.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002650.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002651.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002652.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002653.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002654.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002655.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002656.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0002657.jpg': No such file or directory
# ...
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010984.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010985.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010986.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010987.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010988.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010989.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010990.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010991.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010992.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010993.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010994.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0010995.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011056.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011057.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011058.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011059.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011060.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011061.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011062.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011063.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011064.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011065.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011066.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011067.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011068.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011069.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011105.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011106.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011107.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011108.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011109.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011110.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011111.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011112.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011135.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011136.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011137.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011138.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011139.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011140.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011141.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011142.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011185.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011186.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011187.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011188.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011189.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011190.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011191.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011192.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011193.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011194.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011195.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011196.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011237.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011238.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011239.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011240.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011241.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011242.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011243.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011244.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011245.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011246.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011247.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011248.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011249.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011250.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011251.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011252.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011299.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011300.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011301.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011302.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011303.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011304.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011305.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011306.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011307.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011308.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011309.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011310.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011356.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011357.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011358.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011359.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011360.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011361.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011362.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011363.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011364.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011365.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011366.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011408.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011409.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011410.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011411.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011412.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011413.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011414.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011415.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011416.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011417.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011418.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011419.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011455.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011456.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011457.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011458.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011459.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011460.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011461.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011462.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011463.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011464.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011465.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011466.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011524.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011525.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011526.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011527.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011528.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011529.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011530.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011531.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011532.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011533.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011534.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011535.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011536.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011538.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011539.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011540.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011541.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011542.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011543.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011544.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011545.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011546.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011547.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011548.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011549.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011602.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011603.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011604.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011605.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011606.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011607.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011608.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011609.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011610.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011618.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011619.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011622.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011623.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011624.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011625.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011626.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011627.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011628.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011629.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011630.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011631.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011632.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011633.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011634.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011696.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011697.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011698.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011699.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011700.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011701.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011702.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011703.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011704.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011705.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011706.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011707.jpg': No such file or directory
# cp: cannot stat '/content/dorsal_right_imgs/Hand_0011708.jpg': No such file or directory

# %% [markdown]
# ### EDA

# %%
df
# Out:
#          id  age  gender skinColor  accessories  nailPolish  aspectOfHand  \
# 0         0   27    male      fair            0           0  dorsal right
# 1         0   27    male      fair            0           0  dorsal right
# 2         0   27    male      fair            0           0  dorsal right
# 3         0   27    male      fair            0           0  dorsal right
# 4         0   27    male      fair            0           0  dorsal right
# ...     ...  ...     ...       ...          ...         ...           ...
# 11071  1589   22  female      fair            0           0   palmar left
# 11072  1589   22  female      fair            0           0   palmar left
# 11073  1589   22  female      fair            0           0   palmar left
# 11074  1589   22  female      fair            0           0   palmar left
# 11075  1589   22  female      fair            0           0   palmar left
#
#               imageName  irregularities
# 0      Hand_0000002.jpg               0
# 1      Hand_0000003.jpg               0
# 2      Hand_0000004.jpg               0
# 3      Hand_0000005.jpg               0
# 4      Hand_0000006.jpg               0
# ...                 ...             ...
# 11071  Hand_0011740.jpg               0
# 11072  Hand_0011741.jpg               0
# 11073  Hand_0011742.jpg               0
# 11074  Hand_0011743.jpg               0
# 11075  Hand_0011744.jpg               0
#
# [11076 rows x 9 columns]

# %%
## waste
# def get_raw_image(dataset_dir_path):
#     full_img_np =cv2.imread(f'{dataset_dir_path}/Hand_0000002.jpg')
#     return full_img_np.shape

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11076 entries, 0 to 11075
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              11076 non-null  int64
#  1   age             11076 non-null  int64
#  2   gender          11076 non-null  object
#  3   skinColor       11076 non-null  object
#  4   accessories     11076 non-null  int64
#  5   nailPolish      11076 non-null  int64
#  6   aspectOfHand    11076 non-null  object
#  7   imageName       11076 non-null  object
#  8   irregularities  11076 non-null  int64
# dtypes: int64(5), object(4)
# memory usage: 778.9+ KB

# %%
# df.duplicated().sum() ## get number of duplicate rows

# %%
# df.drop(['imageName','id'],axis=1).mode() ### most common categories

# %%
from IPython.display import display, HTML

# %%
def display_histograms_subplots(df):
    value_counts_dict={}
    cols_to_exclude=['imageName','id']
    plt.figure(figsize=(10,10)).tight_layout(h_pad=2)
    count=0
    for col_name in df.columns.to_list():
        if col_name not in cols_to_exclude:
            value_counts_dict[col_name]=df[col_name].value_counts()
            print(f'value_counts of {col_name} ',value_counts_dict[col_name])
            count+=1
            plt.subplot(3,3,count)
            plt.gca().set_title(col_name)
            df[col_name].hist()
            # if col_name in ['age']:
            #     plt.figure()
            #     plt.title(col_name)
            #     plt.boxplot(df[col_name].to_list())
        # display(value_counts_dict[col_name])
        # display(HTML(value_counts_dict[col_name].to_html()))
# display_histograms_subplots(df)

# %%
def display_histograms(df):
    value_counts_dict={}
    cols_to_exclude=['imageName','id']
    for col_name in df.columns.to_list():
        if col_name not in cols_to_exclude:
            value_counts_dict[col_name]=df[col_name].value_counts()
            print(f'value_counts of {col_name} ',value_counts_dict[col_name])
            plt.figure()
            plt.title(col_name)
            df[col_name].hist()
            if col_name in ['age']:
                plt.figure()
                plt.title(col_name)
                plt.boxplot(df[col_name].to_list())
        # display(value_counts_dict[col_name])
        # display(HTML(value_counts_dict[col_name].to_html()))
# display_histograms(df)

# %%
# import matplotlib.pyplot as plt

'''
dataset_dir_path is path of folder with all hand images

'''

def display_sample_imgs_in_subplots(filenames_list,dataset_dir_path=dataset_dir_path,whole_fig_title=None, img_modify_fn=None):
    plt.figure(figsize=(10,8.5)).tight_layout(h_pad=2)
    # plt.figure(figsize=(10,8)).tight_layout(rect=[0, 0.03, 1, 0.7])


    if whole_fig_title != None:
        plt.suptitle(whole_fig_title) ## set main figure title

    if img_modify_fn == None:
        def img_modify_fn(img):
            return img ## if fn not specified do nothing

    last_i=0
    count=0
    for i,filename in enumerate(filenames_list):
        if (i==0) or (i == last_i+18):
            count+=1
            last_i=i
            plt.subplot(3,3,count)
            image=plt.imread(f'{dataset_dir_path}/{filename}')
            image=img_modify_fn(image)
            plt.imshow(image)
            plt.gca().set_title(filename) ## to set title for subplot
            plt.axis("off")

        if count >= 9:
            break
    plt.show()




def display_column_images(col_name_list,df=df,display_sample_imgs_in_subplots=display_sample_imgs_in_subplots):
    '''
    takes display_sample_imgs_in_subplots function as argument
    '''
    for col_name in col_name_list:
        print(f'\n{col_name}'.upper())
        irreg_imgs_names_list=df[df[col_name] != 0 ]['imageName'].to_list()
        print(df[col_name].value_counts())
        print(f'number of images with {col_name}',len(irreg_imgs_names_list))
        display_sample_imgs_in_subplots(irreg_imgs_names_list,whole_fig_title=col_name)

# %%
col_name_list=['irregularities','accessories','nailPolish']
# df=pd.read_csv('HandInfo.csv')
# display_column_images(col_name_list,display_sample_imgs_in_subplots=display_sample_imgs_in_subplots) ###     takes display_sample_imgs_in_subplots function as argument

# %%
### edge map

# image=cv2.imread(f'{dataset_dir_path}/Hand_0000002.jpg')

# gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# blurred = cv2.GaussianBlur(gray, (3, 3), 0)
# wide = cv2.Canny(blurred, 10, 200)
# mid = cv2.Canny(blurred, 30, 150)
# tight = cv2.Canny(blurred, 240, 250)

# mid.shape
# plt.imshow(mid)

def get_edge_map(image):
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    wide = cv2.Canny(blurred, 10, 200)
    mid = cv2.Canny(blurred, 30, 150)
    tight = cv2.Canny(blurred, 240, 250)
    return mid

img_filename_list_to_plot=df['imageName'].to_list()
# display_sample_imgs_in_subplots(img_filename_list_to_plot,whole_fig_title='EDGE MAP',img_modify_fn=get_edge_map)

# %%
def resize_to_reduce_male_hand_girth(img):
    resized_img=cv2.resize(img,(1200,1000))
    return resized_img

male_img_filenames=df[ df['gender'] == 'male' ]['imageName'].to_list()
female_img_filenames=df[ df['gender'] == 'female' ]['imageName'].to_list()

# display_sample_imgs_in_subplots(male_img_filenames,whole_fig_title='reduced male hand girth',img_modify_fn=resize_to_reduce_male_hand_girth)
# print('\n')
# display_sample_imgs_in_subplots(male_img_filenames,whole_fig_title='original imgs with male hand girth',img_modify_fn=None)
# print('\n')
# display_sample_imgs_in_subplots(female_img_filenames,whole_fig_title='females')

# %%
def make_img_gray(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # blurred = cv2.GaussianBlur(gray, (3, 3), 0)
    # wide = cv2.Canny(blurred, 10, 200)
    # mid = cv2.Canny(blurred, 30, 150)
    # tight = cv2.Canny(blurred, 240, 250)
    return gray

img_filename_list_to_plot=df['imageName'].to_list()
# display_sample_imgs_in_subplots(img_filename_list_to_plot,whole_fig_title='GRAYSCALE',img_modify_fn=make_img_gray)

# %% [markdown]
# ### END OF EDA

# %%
# dorsal_right_imgs_dir_path='/content/dorsal_right_imgs'
# dataset_dir_path=dorsal_right_imgs_dir_path

# %%
def get_col_val_list_in_alphabetical_order_file_names_dict(dataset_dir_path,csv_df):

    '''
    this function is needed in order to make the list of target labels to give as labels argument of
     the keras.utils.image_dataset_from_directory function.
     The keras.utils.image_dataset_from_directory function makes a tensorflow dataset object from the images inside
     a folder. the labels argument should be a list of target variables corresponding to images filenames as listed by
     os.walk('dataset_directory_path') function.

    So what this function does is, to output a dictionary. The dictionary takes the column names in the HandInfo.csv as keys.
    The value in the dictionary corresponding to the column name given as key in the dictionary, is a list,
    containing all the rows in the csv for that single column. The thing is the the rows in this list are ordered such
    that they correspond to the image_file in the order outputted by os.walk('dataset_directory_path').

    '''
    df=csv_df.set_index('imageName')

    from os import walk ## see https://hyp.is/DAhG1PfzEe2Qw3vXNIwQ3Q/www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory
    # print(list(walk(dataset_dir_path))[0][2][0])
    img_filenames_list=list(walk(dataset_dir_path))[0][2]
    col_val_list_in_order_file_names_dict={}


    for col in df.columns.to_list():
        col_val_list_in_order_file_names_dict[col]=[]

        for filename in img_filenames_list:

            col_val_list_in_order_file_names_dict[col].append(df[col][filename])
        # col_val_list_in_order_file_names_dict['gender']=df['gender'][df['imageName'][df['imageName']== filename ].index[0]]
    return col_val_list_in_order_file_names_dict

col_val_list_in_order_file_names_dict=get_col_val_list_in_alphabetical_order_file_names_dict(dataset_dir_path,csv_df=df)
# def make_arr_of_images_and_labels():
#     pass

# %%
### get the num of color channels in the images
def find_num_channels_in_imgs(dataset_dir_path):
    from os import walk ## see https://hyp.is/DAhG1PfzEe2Qw3vXNIwQ3Q/www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory

    import cv2
    first_img_np=cv2.imread(f'{dataset_dir_path}/{list(walk(dataset_dir_path))[0][2][0]}')
    return first_img_np.shape[-1]
num_channels=find_num_channels_in_imgs(dataset_dir_path)

# %%
y_gen_nonenc=col_val_list_in_order_file_names_dict['gender']
 ## so that we know which is 0 and 1; male will be encoded as 0 and female 1

def encode_labels(y_nonenc,categories_list):
    from sklearn.preprocessing import OrdinalEncoder
    y_nonenc=np.array(y_nonenc).reshape(-1,1)
    oe=OrdinalEncoder(categories=[categories_list])
    y_enc_np=oe.fit_transform(y_nonenc)
    return y_enc_np

y_gen_enc_np=encode_labels(y_gen_nonenc,['male','female'])

# %%
len(y_gen_enc_np)
# Out:
# 11076

# %%
### trying to create tensorflow image dataset the way i want; generators are too slow
### check the training speed by using the following; after modifying it of course
'''
from glob2 import glob

x_files = glob('inputs/*.jpg')
y_files = glob('targets/*.jpg')

files_ds = tf.data.Dataset.from_tensor_slices((x_files, y_files))

def process_img(file_path):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, size=(28, 28))
    return img

files_ds = files_ds.map(lambda x, y: (process_img(x), process_img(y))).batch(1)

original, target = next(iter(files_ds))
'''
# Out:
# "\nfrom glob2 import glob\n\nx_files = glob('inputs/*.jpg')\ny_files = glob('targets/*.jpg')\n\nfiles_ds = tf.data.Dataset.from_tensor_slices((x_files, y_files))\n\ndef process_img(file_path):\n    img = tf.io.read_file(file_path)\n    img = tf.image.decode_jpeg(img, channels=3)\n    img = tf.image.convert_image_dtype(img, tf.float32)\n    img = tf.image.resize(img, size=(28, 28))\n    return img\n\nfiles_ds = files_ds.map(lambda x, y: (process_img(x), process_img(y))).batch(1)\n\noriginal, target = next(iter(files_ds))\n"

# %%
! cp '/content/drive/MyDrive/ML-AI_capstone_project/keras_custom_image_dataset.py' '/content/keras_custom_image_dataset.py'

# %%
# from tensorflow.keras.utils import image_dataset_from_directory
## custom version of the keras.utils.image_dataset module, made so as to load only a subset of image files into tf dataset.
import keras_custom_image_dataset as custom_utils

# %%
'''
# import tensorflow.compat.v2 as tf
import tensorflow as tf

def load_image(
    path, image_size, num_channels, interpolation, crop_to_aspect_ratio=False
):
    """Load an image from a path and resize it."""
    img = tf.io.read_file(path)
    img = tf.image.decode_image(
        img, channels=num_channels, expand_animations=False
    )
    if crop_to_aspect_ratio:
        img = keras.utils.image_utils.smart_resize(
            img, image_size, interpolation=interpolation
        )
    else:
        img = tf.image.resize(img, image_size, method=interpolation)
    img.set_shape((image_size[0], image_size[1], num_channels))
    return img

'''
# Out:
# '\n# import tensorflow.compat.v2 as tf\nimport tensorflow as tf\n\ndef load_image(\n    path, image_size, num_channels, interpolation, crop_to_aspect_ratio=False\n):\n    """Load an image from a path and resize it."""\n    img = tf.io.read_file(path)\n    img = tf.image.decode_image(\n        img, channels=num_channels, expand_animations=False\n    )\n    if crop_to_aspect_ratio:\n        img = keras.utils.image_utils.smart_resize(\n            img, image_size, interpolation=interpolation\n        )\n    else:\n        img = tf.image.resize(img, image_size, method=interpolation)\n    img.set_shape((image_size[0], image_size[1], num_channels))\n    return img\n\n'

# %%
img_resize_shape=(240,320)
# img_size_tuple=(img_resize_shape[0],img_resize_shape[1],num_channels)

test_fraction=0.1
seed=12
'''
The keras.utils.image_dataset_from_directory function makes a tensorflow dataset object from the images inside
a folder.
see https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory
 the labels argument should be a list of target variables corresponding to images filenames as listed by
os.walk('dataset_directory_path') function.
'''

'''
train_img_set_tfds, test_img_set_tfds=image_dataset_from_directory(
    dataset_dir_path,
    labels=y_gen_enc_np.flatten().tolist(),
    # labels=None,

    validation_split=test_fraction,
    subset='both',
    seed=seed,
    image_size=img_resize_shape,
    batch_size=16
    )

'''

###[[2023-06-14]]-1134-30
df_subset=df[(df['aspectOfHand'] == 'palmar right') & (df['accessories'] == 0)]
subset_image_paths=[  f'{dataset_dir_path}/{i}' for i in df_new['imageName'] ]
subset_labels= encode_labels(df_new['gender'],['male','female'])

## ignores the first directory argument (but i kept it just so as to prevent any unforseen errors)
## makes images from the files given in list given as image_paths argument.
train_img_set_tfds, test_img_set_tfds=custom_utils.image_dataset_from_directory(
    dataset_dir_path,
    # labels=y_gen_enc_np.flatten().tolist(),
    labels=subset_labels.flatten().tolist(),

    validation_split=test_fraction,
    subset='both',
    seed=seed,
    image_size=img_resize_shape,
    batch_size=16,
    image_paths=subset_image_paths,
    # load_image_fn=load_image

    )

small_train=train_img_set_tfds.take(100)
# Out:
# Using 2532 files for training.
# Using 281 files for validation.

# %%
# small_train.cardinality().numpy()

# %%
# small_train=small_train.unbatch()
# small_train.cardinality().numpy()
#

# %%
# ## checking if the contents of the tensorflow dataset obj are images as intended
count=0
for i,j in small_train:
    count+=1
    if count==1:
        print(i.numpy().shape)
        print(j.numpy())

    else:
        break
# print(count)

# %%
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Input, Dense, concatenate, Conv2D, MaxPooling2D, Dropout, Rescaling, RandomFlip, RandomRotation

# %%
# !pip install keras_cv &> /dev/null
import keras_cv

# %%
# import matplotlib.pyplot as plt
# len(train_img_set_tfds.take(1))
# # plt.figure(figsize=(10, 10))
# for image,label in train_img_set_tfds.take(1):
#     plt.imshow(image.numpy().astype('uint8'))
#     plt.title(int(label))
#     plt.axis('off')

# %%
img_size_tuple=(img_resize_shape[0],img_resize_shape[1],num_channels)

print(img_size_tuple )

# %%
import tensorflow.keras as keras

# %%
img_size_tuple=(img_resize_shape[0],img_resize_shape[1],num_channels)


def build_img_net(img_size_tuple):
    input_layer=Input(shape=img_size_tuple )

    ## to convert images to grayscale
    # import keras_cv
    # keras_cv.layers.Grayscale(output_channels=1) ## see https://keras.io/api/keras_cv/layers/preprocessing/grayscale/


    data_augmentation = Sequential( ### see https://keras.io/api/layers/preprocessing_layers/image_augmentation/
        [
            RandomFlip("horizontal"),
            RandomRotation(0.1),
            # keras.layers.RandomCrop( height=120,width=100) ## not good might cut off fingers when cropping
            # keras.layers.RandomZoom(height=(-0.3,0.3)) ## won't help in basic learning ; required only when trying to learn random internet images

        ]
    ) ## see https://keras.io/examples/vision/image_classification_from_scratch/
    x=data_augmentation(input_layer)
    x = Rescaling(1./255)(x)



    conv_nodes=(16,32,64)
    ##see  https://pyimagesearch.com/2019/02/04/keras-multiple-inputs-and-mixed-data/
    for f in conv_nodes:
        x= Conv2D(f, (3, 3), padding="same",activation='relu')(x)
        # x = Activation("relu")(x)
        # x = BatchNormalization(axis=chanDim)(x)
        x= MaxPooling2D(pool_size=(2, 2))(x)
        # x= Dropout(0.2)(x)
    x= Flatten()(x)
    x = Dense(32,activation='relu')(x)

    x= Dense(16,activation='relu')(x)

    x =Dense(4,activation='relu')(x)
    img_net=Model(inputs=[input_layer],outputs=x)
    return img_net

# img_size_tuple=(img_resize_shape[0],img_resize_shape[1],num_channels)
# img_net=build_img_net(img_size_tuple)

### RESNET

def make_resnet(img_size_tuple):
    input_layer=Input(shape=img_size_tuple )
    # resnet_model = keras.applications.resnet50.ResNet50(weights= 'imagenet', include_top=False, input_shape= img_size_tuple)
    # inputs = keras.Input(shape=input_shape)
    x = Rescaling(1.0 / 255)(input_layer)  # Rescale inputs

    x = keras_cv.layers.Grayscale()(x) ## [[2023-06-03]]-1222-23

    # resnet_model = keras.applications.resnet50.ResNet50(weights= 'imagenet', include_top=False, input_shape= img_size_tuple)
    # resnet_model = keras.applications.resnet50.ResNet50(weights= 'imagenet', input_tensor=x ,include_top=False)

    ### this resnet was used for training my models :-
    resnet_model = keras.applications.resnet50.ResNet50(weights= None, input_tensor=x ,include_top=False) ## try None weights [[2023-06-03]]-0934-50
    # vgg16_model = keras.applications.VGG16(weights= None, input_tensor=x ,include_top=False)
    x= resnet_model.output
    x=Flatten()(x)
    ### keeping no. of dense nodes as square roots of previous layer nodes as suggested in pyimagesearch article [[2023-05-29]]-1934-06
    x=Dropout(0.4)(x)
    # x= Dense(512,activation='relu',name='dense512_arjun')(x)
    x= Dense(512,name='dense512_arjun')(x)

    x=keras.layers.Activation('relu')(x)
    x=Dropout(0.1)(x)
    x= Dense(25,name='dense25_arjun')(x)
    x=keras.layers.Activation('relu')(x)

    x= Dense(10,name='dense10_arjun')(x)
    x=keras.layers.Activation('relu')(x)



    # x = keras.layers.GlobalAveragePooling2D()(x) ## got these layers from dwivedi github code
    # x = keras.layers.Dropout(0.7)(x)
    model = Model(inputs= input_layer , outputs=x)
    return model

# resnet_model = keras.applications.resnet50.ResNet50(weights= 'imagenet', include_top=False, input_shape= img_size_tuple)

def make_vgg16_net(img_size_tuple):
    input_layer=Input(shape=img_size_tuple )
    # resnet_model = keras.applications.resnet50.ResNet50(weights= 'imagenet', include_top=False, input_shape= img_size_tuple)
    # inputs = keras.Input(shape=input_shape)
    x = Rescaling(1.0 / 255)(input_layer)  # Rescale inputs

    x = keras_cv.layers.Grayscale()(x) ## [[2023-06-03]]-1222-23

    # resnet_model = keras.applications.resnet50.ResNet50(weights= 'imagenet', include_top=False, input_shape= img_size_tuple)
    # resnet_model = keras.applications.resnet50.ResNet50(weights= 'imagenet', input_tensor=x ,include_top=False)

    ### this resnet was used for training my models :-
    # resnet_model = keras.applications.resnet50.ResNet50(weights= None, input_tensor=x ,include_top=False) ## try None weights [[2023-06-03]]-0934-50
    vgg16_model = keras.applications.VGG16(weights= None, input_tensor=x ,include_top=False)
    x= vgg16_model.output
    x=Flatten()(x)
    ### keeping no. of dense nodes as square roots of previous layer nodes as suggested in pyimagesearch article [[2023-05-29]]-1934-06
    x=Dropout(0.4)(x)
    # x= Dense(512,activation='relu',name='dense512_arjun')(x)
    x= Dense(512,name='dense512_arjun')(x)

    x=keras.layers.Activation('relu')(x)
    x=Dropout(0.1)(x)
    x= Dense(25,name='dense25_arjun')(x)
    x=keras.layers.Activation('relu')(x)

    x= Dense(10,name='dense10_arjun')(x)
    x=keras.layers.Activation('relu')(x)



    # x = keras.layers.GlobalAveragePooling2D()(x) ## got these layers from dwivedi github code
    # x = keras.layers.Dropout(0.7)(x)
    model = Model(inputs= input_layer , outputs=x)
    return model



# input_nets=[make_resnet(img_size_tuple)]
input_nets=[make_vgg16_net(img_size_tuple)]

# input_nets=[resnet_model]


def make_final_keras_model(inputs_nets:list):
    ## this function is intended to combine one net that takes image
    ## as input and another that takes the metadata from the csv as input, together to form one single
    ## neural net

    ## but for now let's just try with the image net only
    x=input_nets[0].output
    # x = keras.layers.GlobalAveragePooling2D()(x)
    # x = keras.layers.Dropout(0.7)(x)
    # x= Dense(1,activation='sigmoid',name='dense1sig')(x) ## output layer to predict gender
    x= Dense(1,name='dense1sig')(x) ## output layer to predict gender
    x=keras.layers.Activation('sigmoid')(x) ## output layer to predict gender

    final_model= Model(inputs=input_nets[0].input,outputs=x)
    return final_model




final_model=make_final_keras_model(input_nets)

# from tensorflow.keras.utils import plot_model
# plot_model(final_model, show_shapes=True)

# %%
# ! du -sh /content/drive/MyDrive/ML-AI_capstone_project/models | awk '{print $1}'

# %%
# final_model.summary()

# %%
# pretrain_model=keras.models.load_model('/content/drive/MyDrive/ML-AI_capstone_project/models/2023-05-29-08-36_arjun_trained_model_20_epoch_resnet')
# final_model=pretrain_model

# %%
# final_model=keras.models.load_model('/content/drive/MyDrive/ML-AI_capstone_project/models/m_2023-06-03-1415_model_81_epochs')

final_model=keras.models.load_model('/content/drive/MyDrive/ML-AI_capstone_project/models/m_2023-06-03-1415_model')

# %%
### training
from keras.optimizers import SGD, Adam,RMSprop
final_model.compile(
    # optimizer=SGD(0.01),
    optimizer=Adam(),

    # optimizer=RMSprop(lr=0.01),

    # optimizer=SGD(lr=0.01),
    # optimizer=Adam(lr=0.001),

    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
###### ! rm -r '/content/drive/MyDrive/ML-AI_capstone_project/models/callback_backup2'
clear_gdrive_trash()

# %%
from datetime import datetime
timestamp=datetime.now().strftime('%Y-%m-%d-%H%M')

# model_name=f'm_2023-06-03-1415'
model_name=f'm_2023-06-13-2309_dorsal'



with open(f'{drive_project_folder_path}/models/{model_name}_info.txt','w') as f:
    f.write('''
        m_2023-06-13-2309_dorsal
        using 1415 resnet trained model...

    ''')

with open(f'{drive_project_folder_path}/models/{model_name}_personal_log.txt','a+') as f:
    f.write(f'''
        {datetime.now().strftime('%Y-%m-%d-%H%M')}

    ''')
with open(f'{drive_project_folder_path}/models/{model_name}_summary.txt','w') as f:
    f.write(f''' img_resize_shape is {img_resize_shape}
    {final_model.optimizer.__class__.__name__}

            {final_model.optimizer.get_config()}

    {final_model.summary()}

    ''')

! mkdir '/content/drive/MyDrive/ML-AI_capstone_project/models/callback_backup'
! mkdir '/content/drive/MyDrive/ML-AI_capstone_project/models/callback_checkpoint'

backup_dir='/content/drive/MyDrive/ML-AI_capstone_project/models/callback_backup'
checkpoint_filepath=f'{drive_project_folder_path}/models/callback_checkpoint'

backup_callback = keras.callbacks.BackupAndRestore(backup_dir=backup_dir)
reduce_lr_plateau=keras.callbacks.ReduceLROnPlateau()
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='accuracy',
    mode='max',
    save_best_only=True)
csvlogger_callback=keras.callbacks.CSVLogger(
    filename=f'{drive_project_folder_path}/models/{model_name}_CSV_epochs_stats.csv',
    append=True
    )


clear_gdrive_trash()

# %%
# callbacks_list=[backup_callback,reduce_lr_plateau,model_checkpoint_callback,csvlogger_callback]
callbacks_list=[reduce_lr_plateau,model_checkpoint_callback,csvlogger_callback]
# callbacks_list=[model_checkpoint_callback,csvlogger_callback]
# callbacks_list=[csvlogger_callback]

# callbacks_list=[]
final_model.fit(
    train_img_set_tfds,
    # small_train,
    # y=y_gen_enc,
    epochs=50,
    validation_data=test_img_set_tfds,
    # batch_size=5,
    class_weight={0:(1/3967), 1:(1/7109)},
    callbacks=[callbacks_list]
)
clear_gdrive_trash()

# %%
  # ! du -sh /content/drive/MyDrive/ML-AI_capstone_project/models/m_2023-06-03-1415_model_81_epochs

# %%
# ! find /content/ -name '*ckpt*'

# %%
# final_model.save_weights(f'{drive_project_folder_path}/models/2023-05-29_weights_SGD_resnet')
# final_model.save_weights(f'{drive_project_folder_path}/models/2023-06-03_512dense_240x320res_adam_resnet_noimagenet')
final_model.save(f'{drive_project_folder_path}/models/{model_name}_model')

# %%
# callbacks_list=[backup_callback,reduce_lr_plateau,model_checkpoint_callback,csvlogger_callback]
callbacks_list=[reduce_lr_plateau,model_checkpoint_callback,csvlogger_callback]
# callbacks_list=[model_checkpoint_callback,csvlogger_callback]
# callbacks_list=[csvlogger_callback]

# callbacks_list=[]
final_model.fit(
    train_img_set_tfds,
    # small_train,
    # y=y_gen_enc,
    epochs=50,
    validation_data=test_img_set_tfds,
    # batch_size=5,
    class_weight={0:(1/3967), 1:(1/7109)},
    callbacks=[callbacks_list]
)
clear_gdrive_trash()

final_model.save(f'{drive_project_folder_path}/models/{model_name}_model')

# %% [markdown]
# ### model evaluation

# %%
import tensorflow.keras as keras
# final_model=keras.models.load_model('/content/drive/MyDrive/ML-AI_capstone_project/models/m_2023-06-03-1415_model')

# %%
# from keras.optimizers import SGD, Adam,RMSprop
# final_model.compile(
#     optimizer=SGD(0.01),
#     # optimizer=RMSprop(lr=0.01),

#     # optimizer=SGD(lr=0.01),
#     # optimizer=Adam(lr=0.001),

#     loss="binary_crossentropy",
#     metrics=["accuracy"]
# )
# final_model.evaluate(test_img_set_tfds)

# %%
eval_accuracy_keras=0.6411

# %%
# pred_obj=final_model.predict(test_img_set_tfds)

# %%
# import pickle

# exampleObj = pred_obj

# fileObj = open(f'{drive_project_folder_path}/models/2023-06-11_y_pred_np_arr.pkl', 'wb')
# pickle.dump(exampleObj,fileObj)
# fileObj.close()

# %%
import pickle
pred_obj=pickle.load(open(f'{drive_project_folder_path}/models/2023-06-11_y_pred_np_arr.pkl','rb'))
print(pred_obj.shape)
count=0
for y in pred_obj:
    print(y)
    count+=1
    if count >= 0:
      break

# %%
y_true = np.concatenate([y for x, y in test_img_set_tfds], axis=0)
print(y_true)

# %%
y_true=y_true.astype(np.int)
print(y_true.shape)
print(y_true)

# %%
pred_obj
y_pred=pred_obj > 0.5
y_pred=y_pred.astype(np.int)
y_pred=y_pred.flatten()
print(y_pred)

# %%
from sklearn import metrics
acc=metrics.accuracy_score(y_true,y_pred)
print(acc)

# %%
### to study the accuracy of the classification model (without any hyperparameter tuning)


from sklearn import metrics
from matplotlib import pyplot as plt

### confusion matrix
y_test=y_true
confusion_matrix= metrics.confusion_matrix(y_test,y_pred)
# display_labels=[0,1] ## (manual)
cm_display= metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix )
cm_display.plot()
plt.show()


### accuracy metrics
accuracy= metrics.accuracy_score(y_test,y_pred)
# recall= metrics.recall_score(y_test,y_pred,average='macro')
recall= metrics.recall_score(y_test,y_pred)
recall0= metrics.recall_score(y_test,y_pred,pos_label=0)

precision= metrics.precision_score(y_test,y_pred)
precision0= metrics.precision_score(y_test,y_pred,pos_label=0)

f_score= 2*recall*precision/(recall+precision)

print('accuracy is ',accuracy, '\n')
print('recall for class 1 (female) is ',recall, '\n')
print('precision for class 1 is ',precision, '\n')
print('recall for class 0 (male) is ',recall0, '\n')
print('precision for class 0 is ',precision0, '\n')

print('f_score for class 1 is',f_score, '\n')

# result_dict.update({str(type(algo_class).__name__):{'accuracy':accuracy, 'recall':recall,'precision':precision,'f_score':f_score}})


### bias and variance
# error_rate=1-accuracy
# train_accuracy=  metrics.accuracy_score(y_train,y_train_pred)
# variance_measure=np.abs(train_accuracy - accuracy)
# print('a measure of bias =',error_rate,'\na measure of variance =',variance_measure)

# %%
### confidence interval
error=1-accuracy
const=1.96 ## for 95% confidence interval
n= len(y_test)
delta= const * np.sqrt( (error * (1 - error)) / n)
print(delta)
confidence_interval=[round(np.positive(acc-delta),2),round(acc+delta,2)]
print(f'it is 95% likely that the model will have an accuracy in the interval of {confidence_interval} when predicting unseen data')

# %%
### metrics.roc_auc_score(y_true,pred_obj)

# %% [markdown]
# ### flask

# %%
import tensorflow as tf
import tensorflow.keras as keras

# %%
# final_model=keras.models.load_model('/content/drive/MyDrive/ML-AI_capstone_project/models/m_2023-06-03-1415_model')
img_resize_shape=(240,320)

# %%
### predicting a sample image
'''
sample_img_arr=cv2.imread('/content/Hands/Hands/Hand_0000267.jpg')
def preprocess_sample_img(img,img_size_tuple):
    img_resized_arr=cv2.resize(img,(320,240))
    img_resized_arr = np.expand_dims(img_resized_arr, axis=0)
    # img_resized_arr.shape
    return img_resized_arr


preprocessed_samp_img= preprocess_sample_img(sample_img_arr,(320,240))
sample_pred=final_model.predict(preprocess_sample_img(sample_img_arr,(320,240)))
prediction_probabilities = final_model(preprocessed_samp_img, training=False)[0]
node_val=sample_pred[0,0]

if node_val > 0.5 :
    label='female'
    confidence_leafpy=prediction_probabilities[0]
    # confidence= round((np.abs((node_val-0.5))/0.5)*100,3)
else:
    label='male'
    confidence_leafpy=1-prediction_probabilities[0]

    # confidence= round((np.abs((node_val-0.5))/0.5)*100,3)

output = {
    "label": label,
    "confidence": confidence_leafpy
}

print(output)
'''

# %%
print(prediction_probabilities)

# %% [markdown]
# ### deployment using only flask

# %%
from flask import Flask, render_template, request, jsonify, redirect
import os
from PIL import Image

# %%
# %%bash
# cd '/content/drive/MyDrive/ML-AI_capstone_project'
# ### drive
# mkdir templates
# mkdir -p static/css
# # touch ./templates/index.html
# # touch ./static/css/style.css

# %%
# %%bash
# cd '/content/drive/MyDrive/ML-AI_capstone_project'
# mkdir -p static/img/uploads
# # touch index.html

# %%
! cp '/content/index.html' '/content/drive/MyDrive/ML-AI_capstone_project/templates/index.html'
# ! cp '/content/style.css' '/content/drive/MyDrive/ML-AI_capstone_project/static/css/style.css'

# %%
# app= Flask(__name__)
from pathlib import Path

template_folder_path=Path(f'{drive_project_folder_path}/templates')
static_folder_path=Path(f'{drive_project_folder_path}/static')


app = Flask(__name__, template_folder=template_folder_path , static_folder=static_folder_path)
@app.route('/')
def home():
    return render_template('index.html')

app.config['IMAGE_UPLOADS']=f'{drive_project_folder_path}/static/img/uploads'

def get_image(arg_parser): ### see https://github.com/UPstartDeveloper/plantnet-api/blob/main/util/leaf.py
    '''Returns a Pillow Image given the uploaded image.'''
    args = arg_parser.parse_args()
    image_file = args.image  # reading args from file
    # print(image_file.type())
    return Image.open(image_file)


import tensorflow as tf
def preprocess_img_to_load_into_model(image,img_resize_shape):
    """Converts a PIL.Image into a Tensor of the
    right dimensions
    """
    tensor_image = keras.preprocessing.image.img_to_array(image)
    resized_img = tf.image.resize(tensor_image, [img_resize_shape[0], img_resize_shape[1]])
    final_input = np.expand_dims(resized_img, axis=0)
    return final_input



@app.route('/predict',methods=['POST'])
def predict():
    '''
    For rendering results on HTML GUI
    '''
    if request.method == "POST" :
        if request.files: ## this is an obj that stores the files coming in from the forms ; if there are any files then this will be not nonetype maybe
            image_file= request.files["image"] ## "image" is the name attribute of the html input tag of the type "file" that uploades the image
            print(image_file)
            # image.save(os.path.join(app.config['IMAGE UPLOADS'],image.filename))
            pil_img=Image.open(image_file)
            preprocessed_img= preprocess_img_to_load_into_model(pil_img, img_resize_shape)
            model=final_model
            # node_arr=model.predict(preprocessed_img)
            prediction_probabilities = model(preprocessed_img, training=False)[0]

            node_val=prediction_probabilities[0]
            # node_val=node_arr[0,0]
            if node_val > 0.5 :
                label='female'
                confidence_leafpy=prediction_probabilities[0]
            else:
                label='male'
                confidence_leafpy=1-prediction_probabilities[0]

            output = {
                "label": label,
                "confidence": f'{confidence_leafpy}%'
            }
    # int_features = [int(x) for x in request.form.values()]
    # final_features = [np.array(int_features)]
    # prediction = model.predict(final_features)


    return render_template('index.html',
                           prediction_text=f"Gender of the person to which the hand image in the file {image_file.filename} belongs to, was predicted as {output['label']}")



# if __name__ == "__main__":
#     app.run(debug=True)

# %%
! pip install flask_ngrok
from flask_ngrok import run_with_ngrok
# got from https://stackoverflow.com/questions/70342717/colab-unable-to-access-webpage-using-flask-ngrok
! pip install pyngrok==4.1.1
#### ! ngrok authtoken '2R2XpYI71tb0zvlkZgAtXyFLJSt_4DYRZFVTDxumD2bNABgxv' ### old authtoken

# %%
! ngrok authtoken '2R68KQX5VjPA4mIZIr7uB5lqgOU_2Xzrqfy8jk8FJryx7SSo5'

# %%
# ! killall ngrok

# %%
run_with_ngrok(app)
app.run()

# %% [markdown]
# ### flask-restplus

# %%
## code source :  https://blog.devgenius.io/how-to-deploy-keras-models-to-production-beginners-welcome-1fbfab19d3f6
# Prevent ImportErrors w/ flask
! pip install werkzeug==2.0.3
# from collections.abc import MutableMapping

import werkzeug
werkzeug.cached_property = werkzeug.utils.cached_property
from werkzeug.datastructures import FileStorage
### ML/Data processing
# import tensorflow.keras as keras
# from tensorflow.keras.models import load_model
### RESTful API packages

# import flask.scaffold
# flask.helpers._endpoint_from_view_func = flask.scaffold._endpoint_from_view_func
! pip install flask==2.1.3
from flask import Flask
import flask.scaffold
flask.helpers._endpoint_from_view_func = flask.scaffold._endpoint_from_view_func
! pip install flask-restplus

# %%
# %%bash
#
# # cat '/usr/local/lib/python3.10/dist-packages/flask_restplus/model.py' | sed 's/from collections import OrderedDict, MutableMapping/from collections import OrderedDict\nfrom collections.abc import MutableMapping/' > '/usr/local/lib/python3.10/dist-packages/flask_restplus/model.py'
#
# # cat '/usr/local/lib/python3.10/dist-packages/flask_restplus/model.py'

# %%
# flask_restplus_package_installed_directory='/usr/local/lib/python3.10/dist-packages/flask_restplus'
# with open( '/usr/local/lib/python3.10/dist-packages/flask_restplus/model.py' ,'r+') as f:
#     f_str=f.read()
#     f_str.replace('from collections import OrderedDict, MutableMapping','''
# # from collections import OrderedDict, MutableMapping
# ### arjun commented the above import and replaced it with the
# ### following import [[2023-06-10]]-1944-57
# from collections import OrderedDict
# from collections.abc import MutableMapping
# ''')
#     f.write(f_str)
#     print(f_str)


from flask_restplus import Api, Resource
from flask import Flask
import cv2

# %%
app = Flask(__name__)



api = Api(app, version="1.0", title="HandGender API",
description="Identify gender from hand images")
ns = api.namespace("Gender prediction from hand image", description="Predicts gender from hand image ")

# %% [markdown]
# <!--  -->

# %%
# app = Flask(__name__)



# api = Api(app, version="1.0", title="HandGender API",
# description="Identify gender from hand images")
# ns = api.namespace("namespace_name", description="namespace_desc_arjun")



# Use Flask-RESTPlus argparser to process user-uploaded images
arg_parser = api.parser()
arg_parser.add_argument('image', location='files',
                        type=FileStorage, required=True)


model=final_model


from PIL import Image
def get_image(arg_parser): ### see https://github.com/UPstartDeveloper/plantnet-api/blob/main/util/leaf.py
    '''Returns a Pillow Image given the uploaded image.'''
    args = arg_parser.parse_args()
    image_file = args.image  # reading args from file
    # print(image_file.type())
    return Image.open(image_file)

# def preprocess_img_to_load_into_model(img,img_resize_shape)
#     img_resized_arr=cv2.resize(img,(320,240))
#     img_resized_arr = np.expand_dims(img_resized_arr, axis=0)
#     # img_resized_arr.shape
#     return img_resized_arr

# import tensorflow as tf
def preprocess_img_to_load_into_model(image,img_resize_shape):
    """Converts a PIL.Image into a Tensor of the
    right dimensions
    """
    tensor_image = keras.preprocessing.image.img_to_array(image)
    resized_img = tf.image.resize(tensor_image, [img_resize_shape[0], img_resize_shape[1]])
    final_input = np.expand_dims(resized_img, axis=0)
    return final_input


@ns.route("/prediction")
class CNNPrediction(Resource):
    """Takes in the image, to pass to the CNN"""
    @api.doc(parser=arg_parser,
             description="Upload dorsal or ventral image of hand with a clear background to predict gender of the person to which the hand belongs.")
    def post(self):
        # A: get the image
        image = get_image(arg_parser)

        # B: preprocess the image
        # final_image = leaf.preprocess_image(image)
        # preprocessed_image=cv2.resize(image,(240,320))
        preprocessed_image=preprocess_img_to_load_into_model(image,img_resize_shape)

        # C: make the prediction
        # prediction = leaf.predict_leaf_health(model, final_image)
        node_arr = model.predict(preprocessed_image)

        node_val=node_arr[0,0]
        if node_val > 0.5 :
            label='female'
            confidence_leafpy=prediction_probabilities[0]
        else:
            label='male'
            confidence_leafpy=1-prediction_probabilities[0]

        output = {
            "label": label,
            "confidence": f'{confidence_leafpy}%'
        }
        # prediction='test_string'
        ##### return the classification
        return output

# %%
# app.run()

# %%
# !pip install flask-ngrok
# !pip install flask-bootstrap

# %%
# ## got from https://stackoverflow.com/questions/70342717/colab-unable-to-access-webpage-using-flask-ngrok
# ! pip install pyngrok==4.1.1
# # ! ngrok authtoken '2R2XpYI71tb0zvlkZgAtXyFLJSt_4DYRZFVTDxumD2bNABgxv' ### old authtoken
# ! ngrok authtoken '2R68KQX5VjPA4mIZIr7uB5lqgOU_2Xzrqfy8jk8FJryx7SSo5'

# %%
from flask_ngrok import run_with_ngrok
# run_with_ngrok(app)
# app.run()

# %%
run_with_ngrok(app)
app.run()

# %%
  # from flask import Flask
  # from flask_ngrok import run_with_ngrok

  # app = Flask(__name__)
  # run_with_ngrok(app)  # Start ngrok when app is run

  # @app.route("/")
  # def hello():
  #     return "Hello World!"

  # if __name__ == '__main__':
  #     app.run()

# %% [markdown]
# ### OTHER THINGS

# %%
with open(f'{drive_project_folder_path}/models/{model_name}_info.txt','a') as f:
    f.write(f'''
        m_2023-06-03-1415 model
        trained on small_train using .take(100)
        aimed for 100 epochs
        accuracy seems to be stuck at 65% after 68 epochs
        so trying to not use reducelearningrate_on_plateau and start with default adam
        learning rate (probably 0.001) - did 13 more epochs with that but still no improvement
        Saved with total 81 epoch model
        loaded that saved model ; now let's train with SGD as optimizer [[2023-06-03]]-2143-52
        trained 10 epochs with sgd as optimizer; and saved the model as m_2023-06-03-1415_model [[2023-06-03]]-2159-55

        reduced the batch size to 8 [[2023-06-03]]-2206-07 and added the lr plateau callback

        OVERNIGHT TRAINING COMPLETE {datetime.now()}

    ''')

# %%
clear_gdrive_trash()
from keras.optimizers import SGD, Adam,RMSprop
final_model.compile(
    optimizer=RMSprop(0.01),
    # optimizer=RMSprop(lr=0.01),

    # optimizer=SGD(lr=0.01),
    # optimizer=Adam(lr=0.001),

    loss="binary_crossentropy",
    metrics=["accuracy"]
)
# callbacks_list=[backup_callback,reduce_lr_plateau,model_checkpoint_callback,csvlogger_callback]
callbacks_list=[reduce_lr_plateau,model_checkpoint_callback,csvlogger_callback]
# callbacks_list=[model_checkpoint_callback,csvlogger_callback]
# callbacks_list=[csvlogger_callback]
with open(f'{drive_project_folder_path}/models/{model_name}_info.txt','a') as f:
    f.write(f'''
        m_2023-06-03-1415 model
        trained on small_train using .take(100)
        aimed for 100 epochs
        accuracy seems to be stuck at 65% after 68 epochs
        so trying to not use reducelearningrate_on_plateau and start with default adam
        learning rate (probably 0.001) - did 13 more epochs with that but still no improvement
        Saved with total 81 epoch model
        loaded that saved model ; now let's train with SGD as optimizer [[2023-06-03]]-2143-52
        trained 10 epochs with sgd as optimizer; and saved the model as m_2023-06-03-1415_model [[2023-06-03]]-2159-55

        reduced the batch size to 8 [[2023-06-03]]-2206-07 and added the lr plateau callback

        OVERNIGHT TRAINING COMPLETE

        {datetime.now()} starting second phase rmsprop ; start from lr=0.01 ;with lrplateau; 100 epochs


    ''')
# callbacks_list=[]
final_model.fit(
    # train_img_set_tfds,
    small_train,
    # y=y_gen_enc,
    epochs=100,
    validation_data=test_img_set_tfds,
    # batch_size=5,
    class_weight={0:(1/3967), 1:(1/7109)},
    callbacks=[callbacks_list]
)

# %%
final_model.save(f'{drive_project_folder_path}/models/{model_name}_model_second_phase')

# %%
# print(f'{drive_project_folder_path}/models/new_architecture')

# %%
# ! du -sh '/content/drive/MyDrive/ML-AI_capstone_project/models/new_architecture' | awk '{print $1}'

# %%
# col_val_list_in_order_file_names_dict['id']

# %% [markdown]
# ### Navoneel

# %%
# img_resize_shape=(240,320)
img_resize_shape=(1000,1000)
img_size_tuple=(img_resize_shape[0],img_resize_shape[1],num_channels)

test_fraction=0.2
seed=12
train_img_set_tfds, test_img_set_tfds=image_dataset_from_directory(
    dataset_dir_path,
    labels=y_gen_enc_np.flatten().tolist(),
    # labels=None,

    validation_split=test_fraction,
    subset='both',
    seed=seed,
    image_size=img_resize_shape,
    batch_size=32
    )

# %%
def net_for_feature_extraction(img_size_tuple):
    input_layer=Input(shape=img_size_tuple )

    ## to convert images to grayscale
    # import keras_cv
    # keras_cv.layers.Grayscale(output_channels=1) ## see https://keras.io/api/keras_cv/layers/preprocessing/grayscale/


    data_augmentation = Sequential( ### see https://keras.io/api/layers/preprocessing_layers/image_augmentation/
        [
            RandomFlip("horizontal"),
            RandomRotation(0.1),
            # keras.layers.RandomCrop( height=120,width=100) ## not good might cut off fingers when cropping
            # keras.layers.RandomZoom(height=(-0.3,0.3)) ## won't help in basic learning ; required only when trying to learn random internet images

        ]
    ) ## see https://keras.io/examples/vision/image_classification_from_scratch/
    x=data_augmentation(input_layer)
    x = Rescaling(1./255)(x)

    '''
    x= Conv2D(32, (3, 3), padding="same",activation='relu')(x)
    x= MaxPooling2D(pool_size=(2, 2))(x)
    x= MaxPooling2D(pool_size=(3, 3))(x)

    # x=keras.layers.BatchNormalization()(x)
    x= Conv2D(32, (3, 3), padding="same",activation='relu')(x)
    '''
    x= Conv2D(32, (3, 3), padding="same",activation='relu',strides=(3,3))(x)
    x= MaxPooling2D(pool_size=(2, 2))(x)
    x= Conv2D(32, (3, 3), padding="same",activation='relu',strides=(3,3))(x)
    x= MaxPooling2D(pool_size=(2, 2))(x)
    x= Conv2D(32, (3, 3), padding="same",activation='relu',strides=(3,3))(x)
    x= MaxPooling2D(pool_size=(2, 2))(x)
    # x= Dropout(512/800)(x)
    x= Flatten()(x)



    # x= MaxPooling2D(pool_size=(2, 2))(x)



    # conv_nodes=(16,32,64)
    # ##see  https://pyimagesearch.com/2019/02/04/keras-multiple-inputs-and-mixed-data/
    # for f in conv_nodes:
    #     x= Conv2D(f, (3, 3), padding="same",activation='relu')(x)
    #     # x = Activation("relu")(x)
    #     # x = BatchNormalization(axis=chanDim)(x)
    #     x= MaxPooling2D(pool_size=(3, 3))(x)
    #     # x= Dropout(0.2)(x)
    # x= Flatten()(x)
    # x = Dense(32,activation='relu')(x)

    # x= Dense(16,activation='relu')(x)

    # x =Dense(4,activation='relu')(x)
    img_net=Model(inputs=[input_layer],outputs=x)
    return img_net
# navoneel_model=net_for_feature_extraction(img_size_tuple)
# navoneel_model.summary()

# %%
### training
from keras.optimizers import SGD, Adam,RMSprop
navoneel_model.compile(
    optimizer=Adam(),
    # optimizer=RMSprop(lr=0.01),

    # optimizer=SGD(lr=0.01),
    # optimizer=Adam(lr=0.001),

    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
callbacks_list=[csvlogger_callback]

# callbacks_list=[]
navoneel_model.fit(
    # train_img_set_tfds,
    small_train,
    # y=y_gen_enc,
    epochs=50,
    # validation_data=test_img_set_tfds,
    # batch_size=5,
    class_weight={0:(1/3967), 1:(1/7109)},
    callbacks=[callbacks_list]
)
clear_gdrive_trash()

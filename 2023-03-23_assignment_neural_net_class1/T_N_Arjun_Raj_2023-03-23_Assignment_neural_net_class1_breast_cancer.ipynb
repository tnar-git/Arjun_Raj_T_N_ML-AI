# %%
import pandas as pd

# %%
data = pd.read_csv("breastcancer.csv")
result_dict={}

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
x = data[[ 'radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']]

# %%
y = data['diagnosis']

# %%
y.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
y  = y.map({"B":0,"M":1})

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,
                                                     test_size=0.2,
                                                     random_state = 134)

# %%
x_train.shape
# Out:
# (455, 30)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
'''
model1 = Sequential()
def make_model_with_specific_params(model,num_layers=3, layer_nodes_list=[32,32,1],layer_activation_fn_list=['relu','relu','sigmoid']):
    for layer_num in range(num_layers):
        if layer_num==0 :
            model.add(Dense(layer_nodes_list[layer_num], input_shape = (30,), activation = layer_activation_fn_list[layer_num]))
        else:
            model.add(Dense(layer_nodes_list[layer_num], activation = layer_activation_fn_list[layer_num]))


# num_layers=3
# num_node_layer1=32
# num_node_layer2=32

model1.add(Dense(32, input_shape = (30,), activation = "relu"))
model1.add(Dense(32, activation = "relu"))
model1.add(Dense(1, activation = "sigmoid"))
model1.summary()


'''
# Out:
# '\nmodel1 = Sequential()\ndef make_model_with_specific_params(model,num_layers=3, layer_nodes_list=[32,32,1],layer_activation_fn_list=[\'relu\',\'relu\',\'sigmoid\']):\n    for layer_num in range(num_layers):\n        if layer_num==0 :\n            model.add(Dense(layer_nodes_list[layer_num], input_shape = (30,), activation = layer_activation_fn_list[layer_num]))\n        else:\n            model.add(Dense(layer_nodes_list[layer_num], activation = layer_activation_fn_list[layer_num]))\n\n\n# num_layers=3\n# num_node_layer1=32\n# num_node_layer2=32\n\nmodel1.add(Dense(32, input_shape = (30,), activation = "relu"))\nmodel1.add(Dense(32, activation = "relu"))\nmodel1.add(Dense(1, activation = "sigmoid"))\nmodel1.summary()\n\n\n'

# %%
'''
optimizer='sgd'
loss = "binary_crossentropy"
compile_metrics = ["accuracy"]

# def make_model_specific_params(model,optimizer='sgd'
# , loss = "binary_crossentropy",compile_metrics = ["accuracy"]):
#     for layer_num in range(num_layers):
#         if layer_num==0 :
#             model.add(Dense(layer_nodes_list[layer_num], input_shape = (30,), activation = layer_activation_fn_list[layer_num]))
#         else:
#             model.add(Dense(layer_nodes_list[layer_num], activation = layer_activation_fn_list[layer_num]))




model1.compile(optimizer = optimizer, loss = loss,
               metrics = compile_metrics)

'''
# Out:
# '\noptimizer=\'sgd\'\nloss = "binary_crossentropy"\ncompile_metrics = ["accuracy"]\n\n# def make_model_specific_params(model,optimizer=\'sgd\'\n# , loss = "binary_crossentropy",compile_metrics = ["accuracy"]):\n#     for layer_num in range(num_layers):\n#         if layer_num==0 :\n#             model.add(Dense(layer_nodes_list[layer_num], input_shape = (30,), activation = layer_activation_fn_list[layer_num]))\n#         else:\n#             model.add(Dense(layer_nodes_list[layer_num], activation = layer_activation_fn_list[layer_num]))\n\n\n\n\nmodel1.compile(optimizer = optimizer, loss = loss,\n               metrics = compile_metrics)\n\n'

# %%
'''
model1.fit(x_train, y_train, epochs = 10)
'''
# Out:
# '\nmodel1.fit(x_train, y_train, epochs = 10)\n'

# %%
'''
# model1.get_metrics_result().numpy()
# optimizer='sgd'
# loss = "binary_crossentropy"
# compile_metrics = ["accuracy"]
# num_layers=3, layer_nodes_list=[32,32,1],layer_activation_fn_list=['relu','relu','sigmoid']
result_dict={}
# accuracy=model1.get_metrics_result()['accuracy'].numpy()

# accuracy=model1.evaluate(x_test,y_test)
trial=1
result_dict.update({trial:{'accuracy':accuracy,'optimizer':optimizer,'loss':loss,
                           'compile_metrics':compile_metrics,
                           'num_layers':num_layers,
                           'layer_nodes_list':layer_nodes_list,
                           'layer_activation_fn_list':layer_activation_fn_list
                           }})

'''
# Out:
# '\n# model1.get_metrics_result().numpy()\n# optimizer=\'sgd\'\n# loss = "binary_crossentropy"\n# compile_metrics = ["accuracy"]\n# num_layers=3, layer_nodes_list=[32,32,1],layer_activation_fn_list=[\'relu\',\'relu\',\'sigmoid\']\nresult_dict={}\n# accuracy=model1.get_metrics_result()[\'accuracy\'].numpy()\n\n# accuracy=model1.evaluate(x_test,y_test)\ntrial=1\nresult_dict.update({trial:{\'accuracy\':accuracy,\'optimizer\':optimizer,\'loss\':loss,\n                           \'compile_metrics\':compile_metrics,\n                           \'num_layers\':num_layers,\n                           \'layer_nodes_list\':layer_nodes_list,\n                           \'layer_activation_fn_list\':layer_activation_fn_list\n                           }})\n\n'

# %%
# default_param_values_dict={'optimizer':'sgd',
#                    'loss':'binary_crossentropy',
#                     'compile_metrics':'accuracy',
#                     'num_layers':3,
#                     'layer_nodes_list':[16,16,1],
#                     'layer_activation_fn_list':['relu','relu','sigmoid']
#                     }


def train_and_test_model_with_specific_params(num_layers=3,
                                              layer_nodes_list=[16,16,1],
                                              layer_activation_fn_list=['relu','relu','sigmoid'],
                                              optimizer='sgd',
                                              loss = "binary_crossentropy",
                                              compile_metrics = ["accuracy"],
                                              epochs=5):
    output_layer=1
    input_shape=(30,)

    model = Sequential()

    default_num_layers=3
    default_num_layer_nodes=16
    default_activation_fn='relu'

    num_layers=int(num_layers)
    epochs=int(epochs)
    
    if type(layer_activation_fn_list) == str :
        layer_activation_fn_list=eval(layer_activation_fn_list)
    if type(layer_nodes_list) == str :
        layer_nodes_list=eval(layer_nodes_list)
    if type(compile_metrics) == str :
        compile_metrics=eval(compile_metrics)
     
        


    if num_layers != default_num_layers :
        print('num_layers is ',num_layers,'; type is ',type(num_layers))
        layer_nodes_list=[1 for i in range(num_layers)]
        layer_activation_fn_list=[1 for i in range(num_layers)]
        for i in range(num_layers):
            if i == (num_layers-1):
                layer_nodes_list[i]=output_layer
                layer_activation_fn_list[i]='sigmoid'

            else:
                layer_nodes_list[i]=default_num_layer_nodes
                layer_activation_fn_list[i]=default_activation_fn

        print('len of layer_nodes_list is ',len(layer_nodes_list))
        print('layer_nodes_list is ',layer_nodes_list)

            

    for layer_num in range(num_layers):
        if layer_num==0 :
            model.add(Dense(int(layer_nodes_list[layer_num]), input_shape = input_shape, activation = layer_activation_fn_list[layer_num]))
        else:
            model.add(Dense(int(layer_nodes_list[layer_num]), activation = layer_activation_fn_list[layer_num]))
    
    model.compile(optimizer = optimizer, loss = loss,
               metrics = compile_metrics)
    
    model.fit(x_train, y_train, epochs = epochs)
    accuracy=model.evaluate(x_test,y_test)[1] 

    
    trial=f'{param_name}={param_value}'
    result_dict.update({trial:{'accuracy':accuracy,
                               'optimizer':optimizer,
                               'loss':loss,
                           'compile_metrics':compile_metrics,
                           'num_layers':num_layers,
                           'layer_nodes_list':layer_nodes_list,
                           'layer_activation_fn_list':layer_activation_fn_list ,
                           'epochs':epochs
                           }})
    print(f'param name is {param_name} ; param_value : {param_value}')
    print(pd.DataFrame(result_dict))
    
    pass

# %%
param_values_dict={'optimizer':['sgd','adam','adadelta','adagrad', 'adamax','ftrl', 'nadam','rmsprop'],
                #    'loss': ['binary_crossentropy']
                    # 'compile_metrics':['accuracy'],
                    'num_layers':[5,7],
                    'layer_nodes_list':[[32,32,1],[16,32,1],[32,16,1]],
                    'layer_activation_fn_list':[['softmax','softmax','sigmoid'],['relu','softmax','sigmoid'],['linear','linear','sigmoid'],['tanh','tanh','sigmoid']],
                   'epochs':[5,10]
                    }
param_names_list=list(param_values_dict.keys())
# print(param_names_list)

result_dict={}

for param_name in param_names_list:
    param_values_list=param_values_dict[param_name]
    for param_value in param_values_list:
        exec(f'train_and_test_model_with_specific_params({param_name}="{param_value}")')
# Out:
# ['optimizer', 'num_layers', 'layer_nodes_list', 'layer_activation_fn_list', 'epochs']
# Epoch 1/5
# 15/15 [==============================] - 1s 3ms/step - loss: 126.8245 - accuracy: 0.5824
# Epoch 2/5
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6884 - accuracy: 0.6308
# Epoch 3/5
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6861 - accuracy: 0.6308
# Epoch 4/5
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6839 - accuracy: 0.6308
# Epoch 5/5
# ...
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6828 - accuracy: 0.6140
# param name is optimizer ; param_value : sgd
#                                   optimizer=sgd         optimizer=adam  \
# accuracy                               0.614035               0.903509
# optimizer                                   sgd                   adam
# loss                        binary_crossentropy    binary_crossentropy
# ...

# %%
result_df=pd.DataFrame(result_dict).transpose()
result_df
# Out:
#                                                     accuracy optimizer  \
# optimizer=sgd                                       0.614035       sgd
# optimizer=adam                                      0.447368      adam
# num_layers=5                                        0.614035       sgd
# num_layers=7                                        0.614035       sgd
# layer_nodes_list=[32, 32, 1]                        0.614035       sgd
# layer_nodes_list=[16, 32, 1]                        0.614035       sgd
# layer_nodes_list=[32, 16, 1]                        0.614035       sgd
# layer_activation_fn_list=['softmax', 'softmax',...  0.614035       sgd
# layer_activation_fn_list=['relu', 'softmax', 's...  0.614035       sgd
# epochs=5                                            0.614035       sgd
# epochs=10                                           0.614035       sgd
# optimizer=adadelta                                  0.385965  adadelta
# ...
